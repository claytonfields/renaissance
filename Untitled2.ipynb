# %%
import os

# %%
load_path = '/home/claytonfields/nlp/code/renaissance/result/test_mlm_itm_a_seed0_is224_ps16_bs32_pgbs64_te1_ts1/version_0/checkpoints/last.ckpt'
load_path
# Out:
# '/home/claytonfields/nlp/code/renaissance/result/test_mlm_itm_a_seed0_is224_ps16_bs32_pgbs64_te1_ts1/version_0/checkpoints/last.ckpt'

# %%
load_split = load_path.split('/')
load_split
# Out:
# ['',
#  'home',
#  'claytonfields',
#  'nlp',
#  'code',
#  'renaissance',
#  'result',
#  'test_mlm_itm_a_seed0_is224_ps16_bs32_pgbs64_te1_ts1',
#  'version_0',
#  'checkpoints',
#  'last.ckpt']

# %%
load_split[-4]
# Out:
# 'test_mlm_itm_a_seed0_is224_ps16_bs32_pgbs64_te1_ts1'

# %%
os.path.split(load_path)
# Out:
# ('/home/claytonfields/nlp/code/renaissance/result/test_mlm_itm_a_seed0_is224_ps16_bs32_pgbs64_te1_ts1/version_0/checkpoints',
#  'last.ckpt')

# %%
path = load_path
drive, path_and_file = os.path.splitdrive(load_path)
print(drive)
path_and_file
# Out:
# '/home/claytonfields/nlp/code/renaissance/result/test_mlm_itm_a_seed0_is224_ps16_bs32_pgbs64_te1_ts1/version_0/checkpoints/last.ckpt'

# %%
path, file = os.path.split(path_and_file)
print(path)
file
# Out:
# /home/claytonfields/nlp/code/renaissance/result/test_mlm_itm_a_seed0_is224_ps16_bs32_pgbs64_te1_ts1/version_0/checkpoints
# 'last.ckpt'

# %%
folders = []
while True:
    path, folder = os.path.split(path)

    if folder != "":
        folders.append(folder)
    else:
        if path != "":
            folders.append(path)

        break

folders.reverse()
folders
# Out:
# ['/',
#  'home',
#  'claytonfields',
#  'nlp',
#  'code',
#  'renaissance',
#  'result',
#  'test_mlm_itm_a_seed0_is224_ps16_bs32_pgbs64_te1_ts1',
#  'version_0',
#  'checkpoints']

# %%
result_dir = folders[-3]
result_dir
# Out:
# 'test_mlm_itm_a_seed0_is224_ps16_bs32_pgbs64_te1_ts1'

# %%
checkpoint_name = file.split("/")[-1][:-5]
checkpoint_name
# Out:
# 'last'

# %%
parsed_string = f"{result_dir}_{checkpoint_name}"
parsed_string
# Out:
# 'test_mlm_itm_a_seed0_is224_ps16_bs32_pgbs64_te1_ts1_last'
